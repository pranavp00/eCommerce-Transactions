# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from datetime import datetime

# %%
products=pd.read_csv('/content/drive/MyDrive/zeotap assignment/Products.csv')
customers=pd.read_csv('/content/drive/MyDrive/zeotap assignment/Customers.csv')
transactions=pd.read_csv('/content/drive/MyDrive/zeotap assignment/Transactions.csv')

# %%
transactions = pd.merge(transactions, products, on='ProductID')

# %%
avg_spending = transactions.groupby('CustomerID')['TotalValue'].mean().reset_index()
avg_spending.columns = ['CustomerID', 'AvgSpending']
customer_features = pd.merge(customers, avg_spending, on='CustomerID', how='left')

# %%
spending = transactions.groupby('CustomerID')['TotalValue'].sum().reset_index()
spending.columns = ['CustomerID', 'Spending']
customer_features = pd.merge(customer_features, spending, on='CustomerID', how='left')

# %%
most_bought_category = transactions.groupby(['CustomerID', 'Category']).size().reset_index(name='Count')
most_bought_category = most_bought_category.loc[most_bought_category.groupby('CustomerID')['Count'].idxmax()]
most_bought_category = most_bought_category[['CustomerID', 'Category']]
most_bought_category.columns = ['CustomerID', 'MostBoughtCat']
customer_features = pd.merge(customer_features, most_bought_category, on='CustomerID', how='left')

# %%
customer_features
# Out:
#     CustomerID        CustomerName         Region  SignupDate  AvgSpending  \
# 0        C0001    Lawrence Carroll  South America  2022-07-10   670.904000
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13   465.685000
# 2        C0003      Michael Rivera  South America  2024-03-07   681.345000
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09   669.360000
# 4        C0005         Laura Weber           Asia  2022-08-15   678.080000
# ..         ...                 ...            ...         ...          ...
# 195      C0196         Laura Watts         Europe  2022-06-07  1245.720000
# 196      C0197    Christina Harvey         Europe  2023-03-21   642.883333
# 197      C0198         Rebecca Ray         Europe  2022-02-27   465.915000
# 198      C0199      Andrea Jenkins         Europe  2022-12-03   494.820000
# 199      C0200         Kelly Cross           Asia  2023-06-11   951.720000
#
#      Spending MostBoughtCat
# 0     3354.52   Electronics
# 1     1862.74      Clothing
# 2     2725.38    Home Decor
# 3     5354.88         Books
# 4     2034.24   Electronics
# ..        ...           ...
# 195   4982.88    Home Decor
# 196   1928.65   Electronics
# 197    931.83      Clothing
# 198   1979.28   Electronics
# 199   4758.60      Clothing
#
# [200 rows x 7 columns]

# %%
customer_features.fillna(0, inplace=True)

# %%
customer_features = pd.get_dummies(customer_features, columns=['MostBoughtCat', 'Region'], drop_first=True)

# %%
scaler = StandardScaler()
numerical_features = ['AvgSpending', 'Spending']
customer_features[numerical_features] = scaler.fit_transform(customer_features[numerical_features])

# %%
customer_features.set_index('CustomerID', inplace=True)
customer_features.drop(columns=['CustomerName', 'SignupDate'], inplace=True)

# %%
similarity_matrix = cosine_similarity(customer_features)

# %%
similarity_df = pd.DataFrame(similarity_matrix, index=customer_features.index, columns=customer_features.index)

# %%
def get_top_similar_customers(customer_id, similarity_df, top_n=3):
    # Exclude the customer itself (similarity score = 1)
    similar_customers = similarity_df[customer_id].drop(customer_id).sort_values(ascending=False).head(top_n)
    return list(zip(similar_customers.index, similar_customers.values))

# %%
lookalike_results = {}
for customer_id in customer_features.index[:20]:
    lookalike_results[customer_id] = get_top_similar_customers(customer_id, similarity_df)

lookalike_df = pd.DataFrame.from_dict(lookalike_results, orient='index', columns=['Lookalike1', 'Lookalike2', 'Lookalike3'])

# %%
lookalike_df
# Out:
#                         Lookalike1                   Lookalike2  \
# C0001  (C0190, 0.9687859885110042)  (C0181, 0.9508502793850823)
# C0002  (C0088, 0.9909935965023925)  (C0134, 0.9610049060745005)
# C0003  (C0052, 0.9837077693404185)  (C0152, 0.9695870377873116)
# C0004  (C0155, 0.9736203742766467)   (C0165, 0.954676278349485)
# C0005  (C0146, 0.9693604545072987)  (C0186, 0.9608486635157301)
# C0006  (C0168, 0.9742038524482126)  (C0171, 0.9728366380385514)
# C0007  (C0140, 0.9724210075734376)    (C0115, 0.90622826330719)
# C0008   (C0038, 0.846103574489786)  (C0189, 0.8446410072492467)
# C0009    (C0010, 0.98080058465479)  (C0111, 0.9780572917364648)
# C0010  (C0111, 0.9950996476027949)    (C0009, 0.98080058465479)
# C0011  (C0137, 0.9623906937702442)   (C0169, 0.960305464636336)
# C0012  (C0104, 0.9583980497440202)  (C0113, 0.9283254711126852)
# C0013  (C0099, 0.9906840022409866)  (C0108, 0.9104224078398291)
# C0014  (C0060, 0.9749465492242092)  (C0172, 0.9375944235803547)
# C0015  (C0036, 0.9812104332071949)  (C0131, 0.9719030690479622)
# C0016  (C0183, 0.9998796055746817)  (C0067, 0.9625565401895951)
# C0017  (C0075, 0.9497390445925782)  (C0081, 0.9142609458793913)
# C0018  (C0117, 0.9724844292433095)  (C0046, 0.9183092348756426)
# C0019  (C0121, 0.9723227592697831)  (C0132, 0.8570780752647247)
# C0020   (C0140, 0.862893468550327)  (C0050, 0.8308370171531926)
#
#                         Lookalike3
# C0001  (C0048, 0.9429693455883603)
# C0002  (C0106, 0.8990914864519157)
# C0003  (C0031, 0.8842150157447252)
# C0004  (C0169, 0.9471664549206747)
# C0005  (C0130, 0.8204288583639459)
# C0006  (C0187, 0.9663392853927287)
# C0007  (C0020, 0.8110113077529856)
# C0008  (C0160, 0.8434158605722757)
# C0009  (C0198, 0.9695360283616481)
# C0010  (C0198, 0.9794764919294137)
# C0011  (C0126, 0.9572360560594388)
# C0012   (C0163, 0.916181070850778)
# C0013  (C0143, 0.8800060930524938)
# C0014  (C0128, 0.9253449695967414)
# C0015  (C0094, 0.8848511992382696)
# C0016  (C0042, 0.8653967948954256)
# C0017  (C0057, 0.9096577828215426)
# C0018  (C0185, 0.8958023411760393)
# C0019  (C0043, 0.8420075444585019)
# C0020  (C0007, 0.8110113077529856)

# %%
lookalike_df.to_csv('Pranav_Pillai_Lookalike.csv', index=False)
